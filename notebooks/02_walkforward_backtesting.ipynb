# %% [markdown]
# # Botsensai 2.0 Research Lab — 02: Walk-Forward Backtesting
#
# This notebook demonstrates out-of-sample walk-forward validation across market regimes, bootstrap PnL confidence intervals, and drawdown analysis.

# %%
from botsensai.config import get_settings
from botsensai.backtest.walkforward import WalkForward
from botsensai.store.db import Database

settings = get_settings()
db = Database(settings.path(settings.db_path))
print(f"Database status: {db.counts()}")
db.close()
