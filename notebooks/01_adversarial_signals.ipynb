# %% [markdown]
# # Botsensai 2.0 Research Lab — 01: Adversarial Signals
#
# This notebook demonstrates exploratory data analysis across all 34 registered adversarial signals in Botsensai, evaluating signal distributions, correlation matrices, and information coefficients.

# %%
import pandas as pd
import numpy as np
from botsensai.config import get_settings
from botsensai.store.db import Database
from botsensai.metrics import metric_catalogue

settings = get_settings()
print(f"Loaded Botsensai settings. Total metrics: {len(metric_catalogue())}")

# %%
catalogue = metric_catalogue()
df_metrics = pd.DataFrame(catalogue)
df_metrics[['metric_id', 'group', 'direction', 'cost', 'latency']]
