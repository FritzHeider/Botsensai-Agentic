# %% [markdown]
# # Botsensai 2.0 Research Lab — 03: On-Chain Topology Forensics
#
# This notebook demonstrates on-chain graph analysis, funder dispersion, insider supply overhang, and sniper bundle detection.

# %%
from botsensai.config import get_settings
from botsensai.dashboard.graph import build_topology_graph, render_topology_html
from botsensai.store.db import Database

settings = get_settings()
db = Database(settings.path(settings.db_path))
print("Ready for topology graph generation.")
db.close()
